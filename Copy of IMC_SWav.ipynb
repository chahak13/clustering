# %%
# !git clone https://github.com/foiv0s/imc-swav-pub.git
# Out:
# Cloning into 'imc-swav-pub'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 35 (delta 13), reused 30 (delta 8), pack-reused 0
# Unpacking objects: 100% (35/35), done.

# %%
cd imc-swav-pub
# Out:
# /content/imc-swav-pub

# %%
# %%capture
# !pip3 install tensorboardX

# %%
# !python train.py --dataset C10 --path ./dataset --size_crops 28 18 \
      --output_dir ./c10 --cpt_name c10.cpt --epochs 25
# Out:
# Namespace(batch_size=256, cpt_load_path=None, cpt_name='c10.cpt', dataset='C10', dev=None, epochs=25, eps=0.05, l2_w=1e-05, learning_rate=0.0005, max_scale_crops=[1.0, 0.4], min_scale_crops=[0.2, 0.08], model_type='resnet18', nmb_crops=[2, 4], nmb_workers=8, output_dir='./c10', path='./dataset', project_dim=128, prototypes=1000, run_name='default_run', size_crops=[28, 18], tau=0.1, warmup=500)
# log_dir: ./c10/default_run
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Using a 32x32 encoder
# ...

# %%
# !python test.py --dataset c10 --path ./dataset --size_crops 28 18 --cpt_load_path ./c10/c10.cpt
# Out:
# Namespace(batch_size=256, cpt_load_path='./c10/c10.cpt', dataset='c10', dev=None, max_scale_crops=[1.0, 0.4], min_scale_crops=[0.2, 0.08], nmb_crops=[2, 4], nmb_workers=8, path='./dataset', size_crops=[28, 18])
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Using a 32x32 encoder
# 11168832
# ***** CHECKPOINTING *****
# Model restored from checkpoint.
# Training epoch 20
# *************************
# Test Clustering  ACC: 0.607, Test Clustering  NMI: 0.506, Test Clustering  ARI: 0.415
